# %%
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# WARNING:tensorflow:From c:\Users\yusuf\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import librosa
import librosa.display
import numpy as np

# %%
def create_spectogram(y):
    spec = librosa.feature.melspectrogram(y=y)
    spec_conv = librosa.amplitude_to_db(spec, ref=np.max)
    return spec_conv

# %%
y, sr = librosa.load("audio/fold1/7061-6-0-0.wav")
print(y, type(y))
print(sr, type(sr))
# Out:
# [-7.4505806e-09  2.9802322e-08  4.8428774e-08 ...  1.0127544e-05
#   2.3271263e-05  7.0009992e-06] <class 'numpy.ndarray'>
# 22050 <class 'int'>

# %%
spec = create_spectogram(y)
plt.imshow(spec)

# %%
#spec = np.reshape(spec, (-1, spec.shape[1], 1) )
print(spec.shape)
plt.imshow(spec)
# Out:
# (128, 97)

# %%
plt.imshow(spec, cmap="gray")

# %%
spec.min()
# Out:
# -80.0

# %%
spec_normalized = (spec - spec.min()) / (spec.max() - spec.min())
spec_normalized *= 255
plt.imshow(spec_normalized, cmap="gray")

# %%
def convert_to_spec(y):
    spec = create_spectogram(y)
    pec_normalized = (spec - spec.min()) / (spec.max() - spec.min()) * 255
